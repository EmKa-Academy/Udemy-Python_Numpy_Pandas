# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
arr = np.array([
                 [[ 0,  1,  2,  3, 0],
                 [ 4,  5,  6,  7, 0]],

                 [[ 8,  9, 10, 11, 0],
                 [12, 13, 14, 15, 0]],

                 [[16, 17, 18, 19, 0],
                 [20, 21, 22, 23, 0]]
                ])

# %%
arr.shape
# Out:
# (3, 2, 5)

# %%
np.array([[ 0,  1,  2,  3, 0],
[ 4,  5,  6,  7, 0]]).shape
# Out:
# (2, 5)

# %%
# Axisler
# axis=0 --> en dışardaki blok
# axis=1 -- > satırlar
# axis=2 -- > sütunlar
arr.shape
# Out:
# (3, 2, 5)

# %%
arr.ndim
# Out:
# 3

# %%
len(arr.shape) == arr.ndim # 3D array
# Out:
# True

# %%
arr.size
# Out:
# 30

# %%
len(arr.flatten())
# Out:
# 30

# %%
len(arr)
# Out:
# 3
