# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
[i for i in range(0, 10, 2)]
# Out:
# [0, 2, 4, 6, 8]

# %%
arr = np.array([i for i in range(20, 60, 2)])
arr
# Out:
# array([20, 22, 24, 26, 28, 30, 32, 34, 36, 38, 40, 42, 44, 46, 48, 50, 52,
#        54, 56, 58])

# %%
arr[[3, 9]]
# Out:
# array([26, 38])

# %%
arr = arr.reshape(4, 5)
arr
# Out:
# array([[20, 22, 24, 26, 28],
#        [30, 32, 34, 36, 38],
#        [40, 42, 44, 46, 48],
#        [50, 52, 54, 56, 58]])

# %%
arr[[1, -1]]
# Out:
# array([[30, 32, 34, 36, 38],
#        [50, 52, 54, 56, 58]])

# %%
arr[[1, -1], [0, 2]]
# Out:
# array([30, 54])

# %%
row_indices = np.array([1, -1])
column_indices = np.array([0, 2])

row_indices, row_indices.shape
# Out:
# (array([ 1, -1]), (2,))

# %%
row_indices_expanded = np.expand_dims(row_indices, axis=-1)
column_indices_expanded = np.expand_dims(column_indices, axis=-1)

# %%
arr
# Out:
# array([[20, 22, 24, 26, 28],
#        [30, 32, 34, 36, 38],
#        [40, 42, 44, 46, 48],
#        [50, 52, 54, 56, 58]])

# %%
row_indices
# Out:
# array([ 1, -1])

# %%
column_indices_expanded
# Out:
# array([[0],
#        [2]])

# %%
arr[row_indices, column_indices]
# Out:
# array([30, 54])

# %%
arr[row_indices, column_indices_expanded]
# Out:
# array([[30, 50],
#        [34, 54]])

# %%
arr[row_indices_expanded, column_indices]
# Out:
# array([[30, 34],
#        [50, 54]])

# %%
arr[row_indices_expanded, column_indices_expanded]
# Out:
# array([[30],
#        [54]])
