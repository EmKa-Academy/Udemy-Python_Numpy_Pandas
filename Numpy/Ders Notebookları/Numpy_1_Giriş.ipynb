# %% [markdown]
# # NumPy Giriş (Numerical Python)

# %%
# !pip install numpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np # alias
np.__version__
# Out:
# '1.22.4'

# %% [markdown]
# ## Array Oluşturmak

# %%
x = np.array([1, 2, 3, 4]) # 1D --> vektor
x
# Out:
# array([1, 2, 3, 4])

# %%
np.shape(x)
# Out:
# (4,)

# %%
x_2d = np.array([[1, 2, 3, 4], 
                 [5, 6, 7, 8]])
x_2d
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
np.shape(x_2d)
# Out:
# (2, 4)

# %%
x_3d = np.array([[[1, 2, 3, 4], 
                 [5, 6, 7, 8]]])
x_3d
# Out:
# array([[[1, 2, 3, 4],
#         [5, 6, 7, 8]]])

# %%
np.shape(x_3d)
# Out:
# (1, 2, 4)

# %%
x_2d.shape
# Out:
# (2, 4)

# %%
np.shape([1, 2, 3, 4])
# Out:
# (4,)
