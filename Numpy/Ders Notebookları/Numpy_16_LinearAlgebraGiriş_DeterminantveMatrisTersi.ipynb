# %%
import numpy as np

np.__version__
# Out:
# '1.22.4'

# %%
arr = np.array([[1, 2], [3, 4]])
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
determinant_arr = np.linalg.det(arr)
determinant_arr
# Out:
# -2.0000000000000004

# %%
# 2x2 (kare satır ve sütun sayısı eşit) matriste determinant hesabı
# 1(a) 2(b)
# 3(c) 4(d) --> a*d - b*c
# 1*4 - 2*3 = -2

# %%
arr2 = np.array([[1, 2, 5], [3, 4, 5]]) # shape (2, 3)
arr2
# Out:
# array([[1, 2, 5],
#        [3, 4, 5]])

# %%
# kare matris olmadığı için çalışmaz
np.linalg.det(arr2)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-10-566ee244bd6e> in <cell line: 1>()
# ----> 1 np.linalg.det(arr2)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in det(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in det(a)
#    2141     a = asarray(a)
#    2142     _assert_stacked_2d(a)
# -> 2143     _assert_stacked_square(a)
#    2144     t, result_t = _commonType(a)
#    2145     signature = 'D->D' if isComplexType(t) else 'd->d'
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _assert_stacked_square(*arrays)
#     201         m, n = a.shape[-2:]
#     202         if m != n:
# --> 203             raise LinAlgError('Last 2 dimensions of the array must be square')
#     204
#     205 def _assert_finite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
arr3 = np.array([[1, 2, 5], [3, 4, 5], [7, 8, 12]]) # shape (3, 3)
arr3
# Out:
# array([[ 1,  2,  5],
#        [ 3,  4,  5],
#        [ 7,  8, 12]])

# %%
np.linalg.det(arr3)
# Out:
# -14.000000000000004

# %%
# Matrisin tersi 
# A matrisimiz var, bunun tersi B olsun.
# A * B = Birim Matris

# %%
I = np.eye(2)
I
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
# arr * arr_ters = I

# %%
np.around(arr @ np.linalg.inv(arr), 3)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
arr5 = np.array([[1, 2], [2, 4]])
np.linalg.det(arr5)
# Out:
# 0.0

# %%
np.around(arr5 @ np.linalg.inv(arr5), 3)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-24-89388d75d9ca> in <cell line: 1>()
# ----> 1 np.around(arr5 @ np.linalg.inv(arr5), 3)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in inv(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in inv(a)
#     543     signature = 'D->D' if isComplexType(t) else 'd->d'
#     544     extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 545     ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     546     return wrap(ainv.astype(result_t, copy=False))
#     547
#
# /usr/local/lib/python3.10/dist-packages/numpy/linalg/linalg.py in _raise_linalgerror_singular(err, flag)
#      86
#      87 def _raise_linalgerror_singular(err, flag):
# ---> 88     raise LinAlgError("Singular matrix")
#      89
# ...
