# %%
import numpy as np

np.__version__
# Out:
# '1.22.4'

# %%
# U10, i ve f

# %%
np.array(["abcdefgh"], dtype = "U4")
# Out:
# array(['abcd'], dtype='<U4')

# %%
np.array([1], dtype = "i8").dtype
# Out:
# dtype('int64')

# %%
np.array([1.0], dtype = "f8").dtype
# Out:
# dtype('float64')

# %%
np.array([-1]).astype("ui8")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-0c980381032f> in <cell line: 1>()
# ----> 1 np.array([-1]).astype("ui8")
#
# TypeError: data type 'ui8' not understood
