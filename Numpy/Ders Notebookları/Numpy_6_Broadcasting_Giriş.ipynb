# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])

# %%
arr1 + arr2
# Out:
# array([5, 7, 9])

# %%
arr1.shape, arr2.shape
# Out:
# ((3,), (3,))

# %%
arr1 + 100 # shape ()
# Out:
# array([101, 102, 103])

# %%
arr3 = np.array([7, 8, 9]) # (3,)

arr4 = np.array([[4, 5, 6], 
                 [10, 11, 12]]) # (2, 3)

# %%
arr4.shape
# Out:
# (2, 3)

# %%
arr3 + arr4
# Out:
# array([[11, 13, 15],
#        [17, 19, 21]])

# %%
arr5 = np.array([7, 8]) # (2,)

arr5 + arr4
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-3ca5b434295e> in <cell line: 3>()
#       1 arr5 = np.array([7, 8]) # (2,)
#       2
# ----> 3 arr5 + arr4
#
# ValueError: operands could not be broadcast together with shapes (2,) (2,3)
