# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %% [markdown]
# View - Shallow Copy
#
# Copy - Deep Copy

# %%
arr = np.array([1, 2, 3])

# %%
id(arr)
# Out:
# 139856960212784

# %%
arr2 = np.array([1, 2, 3])

# %%
id(arr2)
# Out:
# 139856957488656

# %%
arr3 = arr

# %%
id(arr3)
# Out:
# 139856960212784

# %%
arr.shape
# Out:
# (3,)

# %%
arr = np.expand_dims(arr, axis=-1)
arr
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
id(arr3)
# Out:
# 139856960212784

# %%
id(arr)
# Out:
# 139856956477712

# %%
arr3 = arr # no copy

# %%
arr3[1] = 10

# %%
arr
# Out:
# array([[ 1],
#        [10],
#        [ 3]])

# %%
arr3.base
# Out:
# array([ 1, 10,  3])

# %%
arr4 = np.copy(arr) # deep copy

# %%
arr4.base

# %%
arr4[2] = 1500

# %%
arr
# Out:
# array([[ 1],
#        [10],
#        [ 3]])

# %%
dir(arr)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
# ...
