# %%
import numpy as np

np.__version__
# Out:
# '1.22.4'

# %%
arr = np.array([1, 2, 3, "sdf"])
arr
# Out:
# array(['1', '2', '3', 'sdf'], dtype='<U21')

# %%
type(arr[0])
# Out:
# numpy.str_

# %%
arr1 = np.array([("Kaan", 30, 75), ("Emincan", 40, 60)],
         dtype=[("ad", "U10"), 
                ("birinci_sinav", "i4"),
                ("ikinci_sinav", "i4")])
arr1
# Out:
# array([('Kaan', 30, 75), ('Emincan', 40, 60)],
#       dtype=[('ad', '<U10'), ('birinci_sinav', '<i4'), ('ikinci_sinav', '<i4')])

# %%
arr1[0]
# Out:
# ('Kaan', 30, 75)

# %%
arr1['ad']
# Out:
# array(['Kaan', 'Emincan'], dtype='<U10')

# %%
arr1['birinci_sinav']
# Out:
# array([30, 40], dtype=int32)
