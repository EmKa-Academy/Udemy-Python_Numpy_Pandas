# %%
import numpy as np
np.__version__
# Out:
# '1.22.4'

# %%
arr = np.random.rand(3, 4)
arr
# Out:
# array([[0.91282031, 0.58536259, 0.10725436, 0.76871764],
#        [0.73046347, 0.50907044, 0.00857226, 0.90675597],
#        [0.99478384, 0.22667138, 0.74479724, 0.86040166]])

# %%
arr.shape
# Out:
# (3, 4)

# %%
arr.max(axis=0)
# Out:
# array([0.99478384, 0.58536259, 0.74479724, 0.90675597])

# %%
arr.flatten()
# Out:
# array([0.91282031, 0.58536259, 0.10725436, 0.76871764, 0.73046347,
#        0.50907044, 0.00857226, 0.90675597, 0.99478384, 0.22667138,
#        0.74479724, 0.86040166])

# %%
arr
# Out:
# array([[0.91282031, 0.58536259, 0.10725436, 0.76871764],
#        [0.73046347, 0.50907044, 0.00857226, 0.90675597],
#        [0.99478384, 0.22667138, 0.74479724, 0.86040166]])

# %%
np.argmin(arr, axis=0)
# Out:
# array([1, 2, 1, 0])

# %%
# İleri seviye yorumlama konusu - temel ML bilgisi ile
# daha iyi anlaşılabilir.
class_probs = np.array([[0.8, 0.2], [0.1, 0.9]])
class_probs
# Out:
# array([[0.8, 0.2],
#        [0.1, 0.9]])

# %%
np.argmax(class_probs, axis=1)
# Out:
# array([0, 1])
