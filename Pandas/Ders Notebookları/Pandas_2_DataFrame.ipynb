# %% [markdown]
# # DataFrame

# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'İsim' : ['Emincan' , 'Ali' , 'Murat' , 'Aslı' , 'Fatma'] ,
    'Yas' : [26,21,25,30,18],
    'İl' : ['Rize' , 'İstanbul' , 'Ankara' , 'İzmir' , 'Eskisehir']
} , index= ['A' , 'B' , 'C' , 'D' , 'E'] )

df
# Out:
#       İsim  Yas         İl
# A  Emincan   26       Rize
# B      Ali   21   İstanbul
# C    Murat   25     Ankara
# D     Aslı   30      İzmir
# E    Fatma   18  Eskisehir

# %% [markdown]
# ## Hazır Datayı Okumak

# %%
# pd.read_csv() # %80
# pd.read_excel() # % 5
# pd.read_json() # %2

# %%
# pd.read_csv('country_table.csv')

# %%
# pd.read_excel('deneme.xlsx')

# %%
# pd.read_json('example_1.json' , typ = 'series')

# %%
df = pd.read_csv('Diamonds.csv')
df
# Out:
#        Unnamed: 0     id  carat        cut color clarity  depth  table  price  \
# 0               0      0   0.23      Ideal     E     SI2   61.5   55.0    326
# 1               1      1   0.21    Premium     E     SI1   59.8   61.0    326
# 2               2      2   0.23       Good     E     VS1   56.9   65.0    327
# 3               3      3   0.29    Premium     I     VS2   62.4   58.0    334
# 4               4      4   0.31       Good     J     SI2   63.3   58.0    335
# ...           ...    ...    ...        ...   ...     ...    ...    ...    ...
# 53935       53935  53935   0.72      Ideal     D     SI1   60.8   57.0   2757
# 53936       53936  53936   0.72       Good     D     SI1   63.1   55.0   2757
# 53937       53937  53937   0.70  Very Good     D     SI1   62.8   60.0   2757
# 53938       53938  53938   0.86    Premium     H     SI2   61.0   58.0   2757
# 53939       53939  53939   0.75      Ideal     D     SI2   62.2   55.0   2757
#
# ...

# %% [markdown]
# # Data Ön İzleme

# %%
df.head(3)
# Out:
#    Unnamed: 0  id  carat      cut color clarity  depth  table  price     x  \
# 0           0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1           1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2           2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05
#
#       y     z    price2
# 0  3.98  2.43       NaN
# 1  3.84  2.31  326000.0
# 2  4.07  2.31  327000.0

# %%
df.tail(2)
# Out:
#        Unnamed: 0     id  carat      cut color clarity  depth  table  price  \
# 53938       53938  53938   0.86  Premium     H     SI2   61.0   58.0   2757
# 53939       53939  53939   0.75    Ideal     D     SI2   62.2   55.0   2757
#
#           x     y     z     price2
# 53938  6.15  6.12  3.74  2757000.0
# 53939  5.83  5.87  3.64        NaN

# %%
df.sample(5)
# Out:
#        Unnamed: 0     id  carat        cut color clarity  depth  table  price  \
# 16450       16450  16450   1.20      Ideal     H     SI1   61.2   60.0   6569
# 21704       21704  21704   0.31      Ideal     E     VS2   61.7   57.0    627
# 4551         4551   4551   0.90  Very Good     J     VS1   62.4   57.0   3643
# 25605       25605  25605   1.60      Ideal     G     VS2   62.2   55.0  14474
# 35182       35182  35182   0.31      Ideal     G      IF   62.0   54.0    891
#
#           x     y     z      price2
# 16450  6.87  6.82  4.19   6569000.0
# 21704  4.35  4.37  2.69    627000.0
# 4551   6.13  6.18  3.84   3643000.0
# 25605  7.50  7.46  4.65  14474000.0
# 35182  4.36  4.38  2.71    891000.0

# %%
df.shape
# Out:
# (53940, 13)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# id            0
# carat         0
# cut           0
# color         0
# clarity       1
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# price2        4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   id          53940 non-null  int64
#  2   carat       53940 non-null  float64
#  3   cut         53940 non-null  object
#  4   color       53940 non-null  object
#  5   clarity     53939 non-null  object
#  6   depth       53940 non-null  float64
#  7   table       53940 non-null  float64
#  8   price       53940 non-null  int64
#  9   x           53940 non-null  float64
#  10  y           53940 non-null  float64
#  11  z           53940 non-null  float64
#  12  price2      53936 non-null  float64
# dtypes: float64(7), int64(3), object(3)
# memory usage: 5.4+ MB

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'carat', 'cut', 'color', 'clarity', 'depth',
#        'table', 'price', 'x', 'y', 'z', 'price2'],
#       dtype='object')

# %%
df.describe()
# Out:
#          Unnamed: 0            id         carat         depth         table  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26969.500000  26969.500000      0.797940     61.749405     57.457184
# std    15571.281097  15571.281097      0.474011      1.432621      2.234491
# min        0.000000      0.000000      0.200000     43.000000     43.000000
# 25%    13484.750000  13484.750000      0.400000     61.000000     56.000000
# 50%    26969.500000  26969.500000      0.700000     61.800000     57.000000
# 75%    40454.250000  40454.250000      1.040000     62.500000     59.000000
# max    53939.000000  53939.000000      5.010000     79.000000     95.000000
#
#               price             x             y             z        price2
# count  53940.000000  53940.000000  53940.000000  53940.000000  5.393600e+04
# mean    3932.799722      5.731157      5.734526      3.538734  3.932977e+06
# ...

# %%
df.describe().T
# Out:
#               count          mean           std       min        25%  \
# Unnamed: 0  53940.0  2.696950e+04  1.557128e+04       0.0   13484.75
# id          53940.0  2.696950e+04  1.557128e+04       0.0   13484.75
# carat       53940.0  7.979397e-01  4.740112e-01       0.2       0.40
# depth       53940.0  6.174940e+01  1.432621e+00      43.0      61.00
# table       53940.0  5.745718e+01  2.234491e+00      43.0      56.00
# price       53940.0  3.932800e+03  3.989440e+03     326.0     950.00
# x           53940.0  5.731157e+00  1.121761e+00       0.0       4.71
# y           53940.0  5.734526e+00  1.142135e+00       0.0       4.72
# z           53940.0  3.538734e+00  7.056988e-01       0.0       2.91
# price2      53936.0  3.932977e+06  3.989521e+06  326000.0  950000.00
#
#                    50%         75%          max
# Unnamed: 0    26969.50    40454.25     53939.00
# id            26969.50    40454.25     53939.00
# carat             0.70        1.04         5.01
# ...

# %% [markdown]
# # Sütun İşlemleri

# %%
df.head(3)
# Out:
#    Unnamed: 0  id  carat      cut color clarity  depth  table  price     x  \
# 0           0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1           1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2           2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05
#
#       y     z    price2
# 0  3.98  2.43       NaN
# 1  3.84  2.31  326000.0
# 2  4.07  2.31  327000.0

# %%
df['depth']
# Out:
# 0        61.5
# 1        59.8
# 2        56.9
# 3        62.4
# 4        63.3
#          ...
# 53935    60.8
# 53936    63.1
# 53937    62.8
# 53938    61.0
# 53939    62.2
# Name: depth, Length: 53940, dtype: float64

# %%
df.depth
# Out:
# 0        61.5
# 1        59.8
# 2        56.9
# 3        62.4
# 4        63.3
#          ...
# 53935    60.8
# 53936    63.1
# 53937    62.8
# 53938    61.0
# 53939    62.2
# Name: depth, Length: 53940, dtype: float64

# %%
df.Unnamed: 0

# %%
df['Unnamed: 0']
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 53935    53935
# 53936    53936
# 53937    53937
# 53938    53938
# 53939    53939
# Name: Unnamed: 0, Length: 53940, dtype: int64

# %%
df['depth']
# Out:
# 0        61.5
# 1        59.8
# 2        56.9
# 3        62.4
# 4        63.3
#          ...
# 53935    60.8
# 53936    63.1
# 53937    62.8
# 53938    61.0
# 53939    62.2
# Name: depth, Length: 53940, dtype: float64

# %%
df[['depth']]
# Out:
#        depth
# 0       61.5
# 1       59.8
# 2       56.9
# 3       62.4
# 4       63.3
# ...      ...
# 53935   60.8
# 53936   63.1
# 53937   62.8
# 53938   61.0
# 53939   62.2
#
# [53940 rows x 1 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  id  carat      cut color clarity  depth  table  price     x  \
# 0           0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1           1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 2           2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05
# 3           3   3   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 4           4   4   0.31     Good     J     SI2   63.3   58.0    335  4.34
#
#       y     z    price2
# 0  3.98  2.43       NaN
# 1  3.84  2.31  326000.0
# 2  4.07  2.31  327000.0
# 3  4.23  2.63       NaN
# 4  4.35  2.75  335000.0

# %%
df[['carat' , 'price']]
# Out:
#        carat  price
# 0       0.23    326
# 1       0.21    326
# 2       0.23    327
# 3       0.29    334
# 4       0.31    335
# ...      ...    ...
# 53935   0.72   2757
# 53936   0.72   2757
# 53937   0.70   2757
# 53938   0.86   2757
# 53939   0.75   2757
#
# [53940 rows x 2 columns]

# %%
df.drop('Unnamed: 0' , axis = 1 , inplace = True)
# df = df.drop('Unnamed: 0' , axis = 1)

# %%
df.head()
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#      price2
# 0       NaN
# 1  326000.0
# 2  327000.0
# 3       NaN
# 4  335000.0

# %%
# df['price'] = df['price'] * 1.3
df['price'] * 1.3
# Out:
# 0         423.8
# 1         423.8
# 2         425.1
# 3         434.2
# 4         435.5
#           ...
# 53935    3584.1
# 53936    3584.1
# 53937    3584.1
# 53938    3584.1
# 53939    3584.1
# Name: price, Length: 53940, dtype: float64

# %%
df['price'] / df['carat']
# Out:
# 0        1417.391304
# 1        1552.380952
# 2        1421.739130
# 3        1151.724138
# 4        1080.645161
#             ...
# 53935    3829.166667
# 53936    3829.166667
# 53937    3938.571429
# 53938    3205.813953
# 53939    3676.000000
# Length: 53940, dtype: float64

# %%
df.head()
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#      price2
# 0       NaN
# 1  326000.0
# 2  327000.0
# 3       NaN
# 4  335000.0

# %%
df['price_per_carat'] = df['price'] / df['carat']

# %%
df.head()
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#      price2  price_per_carat
# 0       NaN      1417.391304
# 1  326000.0      1552.380952
# 2  327000.0      1421.739130
# 3       NaN      1151.724138
# 4  335000.0      1080.645161

# %% [markdown]
# ## Filtreleme

# %%
df.head()
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#      price2  price_per_carat
# 0       NaN      1417.391304
# 1  326000.0      1552.380952
# 2  327000.0      1421.739130
# 3       NaN      1151.724138
# 4  335000.0      1080.645161

# %%
df_simple = pd.DataFrame({'Year' : [1071, 1830, 1776],
                          'Pop' : [80 , 10 , 328],
                          'GDP' : [0.82 , 0.21 , 20.5]} , index= ['Türkiye' , 'Yunanistan' , 'ABD'])
df_simple
# Out:
#             Year  Pop    GDP
# Türkiye     1071   80   0.82
# Yunanistan  1830   10   0.21
# ABD         1776  328  20.50

# %%
# 1800 yılından önce kurulmuş ülkeleri getir.

df_simple[df_simple['Year'] < 1800]
# Out:
#          Year  Pop    GDP
# Türkiye  1071   80   0.82
# ABD      1776  328  20.50

# %%
# Popülasyonu 100'den büyükler gelsin.

df_simple[df_simple['Pop'] > 100]
# Out:
#      Year  Pop   GDP
# ABD  1776  328  20.5

# %%
df.head(3)
# Out:
#    id  carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
#
#      price2  price_per_carat
# 0       NaN      1417.391304
# 1  326000.0      1552.380952
# 2  327000.0      1421.739130

# %%
df[df['clarity'] == 'VS1']
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 2          2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 9          9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05
# 11        11   0.23      Ideal     J     VS1   62.8   56.0    340  3.93  3.90
# 22        22   0.23  Very Good     H     VS1   61.0   57.0    353  3.94  3.96
# 26        26   0.24    Premium     I     VS1   62.5   57.0    355  3.97  3.94
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53901  53901   0.57    Premium     E     VS1   61.6   58.0   2753  5.36  5.33
# 53914  53914   0.84       Good     I     VS1   63.7   59.0   2753  5.94  5.90
# 53918  53918   0.76    Premium     I     VS1   59.3   62.0   2753  5.93  5.85
# 53922  53922   0.70  Very Good     D     VS1   63.1   59.0   2755  5.67  5.58
# 53929  53929   0.71      Ideal     G     VS1   61.4   56.0   2756  5.76  5.73
#
# ...

# %%
# Mantıksal İfadeler
# And --> &
# Or --> |

# %%
df[(df['color'] == 'E') & (df['depth'] > 60)]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 0          0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 8          8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78
# 14        14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75
# 15        15   0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42
# 21        21   0.23  Very Good     E     VS2   63.8   55.0    352  3.85  3.92
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53926  53926   0.71      Ideal     E     SI1   61.9   56.0   2756  5.71  5.73
# 53928  53928   0.79    Premium     E     SI2   61.4   58.0   2756  6.03  5.96
# 53930  53930   0.71    Premium     E     SI1   60.5   55.0   2756  5.79  5.74
# 53932  53932   0.70  Very Good     E     VS2   60.5   59.0   2757  5.71  5.76
# 53933  53933   0.70  Very Good     E     VS2   61.2   59.0   2757  5.69  5.72
#
# ...

# %%
df[(df['price'] > 350) | (df['cut'] == 'Premium')]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 1          1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 3          3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 12        12   0.22    Premium     F     SI1   60.4   61.0    342  3.88  3.84
# 14        14   0.20    Premium     E     SI2   60.2   62.0    345  3.79  3.75
# 15        15   0.32    Premium     E      I1   60.9   58.0    345  4.38  4.42
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
# ...

# %%
# Color'ı 'H' olan VE depth'i 62'den büyük olan satırları getirin.

# %%
# price'ı 1000'den büyük olan VE clarity'si I1 olan kaç tane elmas olduğunu bulalım.

# %%
# carat'ı 3'den büyük olan VEYA derinliği 68'den fazla olan kaç tane elmas olduğunu bulalım.

# %%
# Table'ı 70'den büyük olan VEYA price'ı 1000'den küçük olan kaç tane elmas olduğunu bulalım.

# %%
# Price'ı 400 ile 600 arasında olan satırları getirin. (Bunu henüz görmediniz ama deneyebilirsiniz.)

# %%
# Color'ı E , D veya H olan kaç tane elmas olduğunun sayısını bulun. (Bunu da henüz görmediniz ama deneyebilirsiniz.)

# %%
df[(df['color'] == 'H') & (df['depth'] > 62)]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 37        37   0.31       Good     H     SI1   64.0   54.0    402  4.29  4.31
# 44        44   0.32       Good     H     SI2   63.1   56.0    403  4.34  4.37
# 47        47   0.32       Good     H     SI2   63.8   56.0    403  4.36  4.38
# 71        71   0.30  Very Good     H     SI1   63.1   56.0    554  4.29  4.27
# 72        72   0.30    Premium     H     SI1   62.9   59.0    554  4.28  4.24
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53841  53841   0.80  Very Good     H     SI1   63.8   56.0   2739  5.85  5.91
# 53851  53851   0.71      Ideal     H    VVS1   62.1   57.0   2742  5.67  5.70
# 53897  53897   1.02       Good     H      I1   64.3   63.0   2751  6.28  6.23
# 53899  53899   0.72      Ideal     H    VVS2   62.3   56.0   2752  5.74  5.81
# 53900  53900   0.73      Ideal     H     VS2   62.5   58.0   2752  5.71  5.75
#
# ...

# %%
df[(df['price'] > 1000) & (df['clarity'] == 'I1')].shape[0]
# Out:
# 674

# %%
df[(df['carat'] > 3) | (df['depth'] > 68)].shape[0]
# Out:
# 120

# %%
df[(df['table'] > 70) | (df['price'] < 1000)].shape[0]
# Out:
# 14507

# %%
df[(df['price'] >= 400) & (df['price'] <= 600)]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 30        30   0.23  Very Good     F     VS1   60.0   57.0    402  4.00  4.03
# 31        31   0.23  Very Good     F     VS1   59.8   57.0    402  4.04  4.06
# 32        32   0.23  Very Good     E     VS1   60.7   59.0    402  3.97  4.01
# 33        33   0.23  Very Good     E     VS1   59.5   58.0    402  4.01  4.06
# 34        34   0.23  Very Good     D     VS1   61.9   58.0    402  3.92  3.96
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53635  53635   0.30      Ideal     I    VVS1   62.1   56.0    552  4.30  4.33
# 53636  53636   0.30      Ideal     D     SI1   61.6   57.0    552  4.28  4.32
# 53637  53637   0.30  Very Good     D     SI1   62.5   57.0    552  4.26  4.28
# 53638  53638   0.30      Ideal     D     SI1   61.0   57.0    552  4.29  4.33
# 53639  53639   0.30      Ideal     D     SI1   61.0   56.0    552  4.35  4.37
#
# ...

# %%
df[df['price'].between(400,600)]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 30        30   0.23  Very Good     F     VS1   60.0   57.0    402  4.00  4.03
# 31        31   0.23  Very Good     F     VS1   59.8   57.0    402  4.04  4.06
# 32        32   0.23  Very Good     E     VS1   60.7   59.0    402  3.97  4.01
# 33        33   0.23  Very Good     E     VS1   59.5   58.0    402  4.01  4.06
# 34        34   0.23  Very Good     D     VS1   61.9   58.0    402  3.92  3.96
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53635  53635   0.30      Ideal     I    VVS1   62.1   56.0    552  4.30  4.33
# 53636  53636   0.30      Ideal     D     SI1   61.6   57.0    552  4.28  4.32
# 53637  53637   0.30  Very Good     D     SI1   62.5   57.0    552  4.26  4.28
# 53638  53638   0.30      Ideal     D     SI1   61.0   57.0    552  4.29  4.33
# 53639  53639   0.30      Ideal     D     SI1   61.0   56.0    552  4.35  4.37
#
# ...

# %%
df[df['color'].isin(['E' , 'D' , 'H'])]
# Out:
#           id  carat        cut color clarity  depth  table  price     x     y  \
# 0          0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1          1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2          2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07
# 7          7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11
# 8          8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78
# ...      ...    ...        ...   ...     ...    ...    ...    ...   ...   ...
# 53935  53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76
# 53936  53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75
# 53937  53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68
# 53938  53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12
# 53939  53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87
#
# ...

# %% [markdown]
# # Satır İşlemleri

# %%
# df_simple = pd.DataFrame({'Year' : [1071, 1830, 1776],
#                           'Pop' : [80 , 10 , 328],
#                           'GDP' : [0.82 , 0.21 , 20.5]} , index= ['Türkiye' , 'Yunanistan' , 'ABD'])

# %%
df_simple
# Out:
#             Year  Pop    GDP
# Türkiye     1071   80   0.82
# Yunanistan  1830   10   0.21
# ABD         1776  328  20.50

# %%
# .loc ve .iloc methodlarıyla istediğimiz satırları çekebiliriz.

# %%
df_simple.loc['Yunanistan']
# Out:
# Year    1830.00
# Pop       10.00
# GDP        0.21
# Name: Yunanistan, dtype: float64

# %%
df_simple.loc[['Yunanistan']]
# Out:
#             Year  Pop   GDP
# Yunanistan  1830   10  0.21

# %%
df_simple.iloc[1]
# Out:
# Year    1830.00
# Pop       10.00
# GDP        0.21
# Name: Yunanistan, dtype: float64

# %%
df_simple.iloc[[1]]
# Out:
#             Year  Pop   GDP
# Yunanistan  1830   10  0.21

# %%
df_simple.loc['Türkiye' : 'Yunanistan' ] # Stop noktası dahil.
# Out:
#             Year  Pop   GDP
# Türkiye     1071   80  0.82
# Yunanistan  1830   10  0.21

# %%
df_simple.iloc[0:2] # Stop noktası dahil değil.
# Out:
#             Year  Pop   GDP
# Türkiye     1071   80  0.82
# Yunanistan  1830   10  0.21

# %%
df_simple.loc[['Türkiye' , 'ABD']]
# Out:
#          Year  Pop    GDP
# Türkiye  1071   80   0.82
# ABD      1776  328  20.50

# %%
df_simple.iloc[[0 , 2]]
# Out:
#          Year  Pop    GDP
# Türkiye  1071   80   0.82
# ABD      1776  328  20.50

# %%
# Done
